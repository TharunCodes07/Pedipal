# %%
# %pip install -q groq

# %%
diet_plan = [['sour', 'umami', 'sweet'], ['sweet', 'umami', 'sour'], ['bitter', 'umami', 'sour'], ['bitter', 'umami', 'sour'], ['umami', 'sweet', 'bitter'], ['bitter', 'sweet', 'sweet'], ['sweet', 'sweet', 'sweet']]

# %%
age = 5

# %%
import os
from groq import Groq
from langchain_groq import ChatGroq
llm = ChatGroq(
            groq_api_key='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',
            model_name='llama3-8b-8192')

# %%
from langchain import PromptTemplate

if age<2:
    template = '''
    You are a "Indian" diet planning assistant for children. Make sure that the food that u generate are babies friendly and provide only Indian dishes. Based on the following taste preferences for each day, create a detailed and nutritionally balanced meal plan (breakfast, lunch, and dinner) for each day with actually edible healthy food names as per the rewuested flavours. The plan should include specific food items that match the taste combinations provided. You must use real foods that are suitable for children and ensure that the meal is "simple and practical". 

    the output should not contain any taste name explicitly, avoid non-vergetarian/hard to digest food items and make the foods  easy to eat for a {age} year old child.


    Here’s an example format of what is expected for Day 1:
    - **Breakfast**: Greek yogurt with honey and strawberries , and a slice of sourdough bread .
    - **Lunch**: Grilled chicken with lemon , quinoa , and sautéed mushrooms .
    - **Dinner**: Roasted salmon , mashed sweet potatoes , and a side of steamed broccoli .

    Now generate a complete meal plan with a list of actual food names for each day, providing **actual foods** for each meal in the above format.

    Here is the reference taste preferences for each day, refer to them and  create the meal plan:


    Day 1: {day1}
    Day 2: {day2}
    Day 3: {day3}
    Day 4: {day4}
    Day 5: {day5}
    Day 6: {day6}
    Day 7: {day7}
    '''

else:
    template = '''
    You are a "Indian" diet planning assistant for children. Make sure that the food that u generate are babies friendly and also Indian dishes. Based on the following taste preferences for each day, create a detailed and nutritionally balanced meal plan (breakfast, lunch, and dinner) for each day with actually edible healthy food names as per the rewuested flavours. The plan should include specific food items that match the taste combinations provided. You must use real foods that are suitable for children and ensure variety.

    the output should not contain any taste name explicitly, create a detailed and nutritionally balanced meal plan suitable for a {age} year-old child
    
    Here is the reference taste preferences for each day in the format [Breakfast Flavor, Lunch Flavor, Dineer Flavor], refer to them and create the meal plan, make sure that the food u provide for that meal is predominantly based on the flavor provided:

    Day 1: {day1}
    Day 2: {day2}
    Day 3: {day3}
    Day 4: {day4}
    Day 5: {day5}
    Day 6: {day6}
    Day 7: {day7}

    Here’s an example format of what is expected for Day 1:

    Breakfast: Soft moong dal khichdi (lentil and rice porridge) with mashed carrots and a small dollop of ghee.
    Lunch: Mildly spiced grilled chicken (shredded for easy chewing) with mashed sweet potatoes and soft-cooked spinach (pureed or finely chopped).
    Dinner: Paneer (cottage cheese) cubes sautéed in a little ghee, served with mashed pumpkin and soft, steamed green beans.


    Now generate a complete meal plan with a list of actual food names for each day, providing **actual foods** for each meal in the above format emphasizing on the flavor.

    '''


prompt = PromptTemplate(
    input_variables=["age","day1", "day2", "day3", "day4", "day5", "day6", "day7"],
    template=template
)

# %%
from langchain.chains import LLMChain
def convo(llm):
    # memory = ConversationBufferWindowMemory(k=10, memory_key="chat_history", return_messages=True) 
    conversation = LLMChain(
        llm=llm,
        prompt=prompt,
        verbose=False, 
        # memory=memory
)
    return conversation

# %%
chat = convo(llm)

# %%
from langchain.schema import HumanMessage, SystemMessage

diet = llm.predict(prompt.format(age=6,day1=diet_plan[0],day2=diet_plan[1],day3=diet_plan[2],day4=diet_plan[3],day5=diet_plan[4],day6=diet_plan[5],day7=diet_plan[6]))

print(diet)
# Out:
# Here is the meal plan for each day, taking into account the taste preferences:
#
# **Day 1: ['sour', 'umami', 'sweet']**
#
# * Breakfast: Soft idli (steamed rice cake) with a dollop of rava laddu (a sweet and sour mixture of semolina and dried fruits) and a glass of buttermilk.
# * Lunch: Grilled fish (such as tilapia or cod) marinated in a mixture of lemon juice, yogurt, and spices, served with mashed mango and soft-cooked brown rice.
# * Dinner: Paneer (cottage cheese) cubes sautéed in a mixture of ghee and tamarind paste, served with steamed basmati rice and sautéed bitter melon.
#
# **Day 2: ['sweet', 'umami', 'sour']**
#
# * Breakfast: Sweet poha (flattened rice flakes) with chopped nuts and dried fruits, served with a glass of cold milk.
# * Lunch: Mildly spiced chicken tikka (shredded for easy chewing) with mashed sweet potatoes and soft-cooked spinach (pureed or finely chopped).
# * Dinner: Vegetable biryani (a sweet and savory rice dish) with sautéed onions, carrots, and peas, served with raita (a yogurt-based side dish with cucumber and cumin).
#
# **Day 3: ['bitter', 'umami', 'sour']**
#
# * Breakfast: Bitter gourd (pavakkai) sautéed with onions and garlic, served with whole wheat toast and a glass of orange juice.
# * Lunch: Grilled eggplant (brinjal) with a mixture of yogurt, cumin, and coriander, served with mashed avocado and soft-cooked quinoa.
# * Dinner: Sautéed bitter melon with onions and garlic, served with steamed brown rice and a side of cucumber raita.
#
# **Day 4: ['bitter', 'umami', 'sour']**
#
# * Breakfast: Whole wheat pita bread with a bitter gourd and onion chutney, served with a glass of buttermilk.
# * Lunch: Chicken soup with a bitter flavor profile (made with bitter gourd and herbs), served with a side of whole wheat crackers.
# * Dinner: Sautéed mixed vegetables (including bitter melon and eggplant) with a mixture of yogurt, cumin, and coriander, served with steamed brown rice.
#
# **Day 5: ['umami', 'sweet', 'bitter']**
#
# * Breakfast: Sweet and savory oats with chopped nuts and dried fruits, served with a glass of cold milk.
# * Lunch: Grilled chicken breast with a mixture of soy sauce, honey, and ginger, served with mashed sweet potatoes and soft-cooked broccoli.
# * Dinner: Sautéed mushrooms with onions and garlic, served with steamed basmati rice and a side of cucumber raita.
#
# **Day 6: ['bitter', 'sweet', 'sweet']**
#
# * Breakfast: Whole wheat cookies with a bitter gourd and sweet chutney, served with a glass of cold milk.
# * Lunch: Grilled chicken breast with a mixture of honey and ginger, served with mashed sweet potatoes and soft-cooked carrots.
# * Dinner: Sautéed bitter melon with onions and garlic, served with steamed brown rice and a side of sweet and sour chutney.
#
# **Day 7: ['sweet', 'sweet', 'sweet']**
#
# * Breakfast: Sweet and savory pancakes made with whole wheat flour and topped with honey, served with a glass of cold milk.
# * Lunch: Grilled chicken breast with a mixture of honey and soy sauce, served with mashed sweet potatoes and soft-cooked peas.
# * Dinner: Sautéed mixed vegetables (including sweet potatoes and carrots) with a mixture of honey and soy sauce, served with steamed brown rice.
#
# Please note that these meal plans are designed to be nutritionally balanced and suitable for a 6-year-old child. However, please consult with a pediatrician or a registered dietitian before making any changes to your child's diet.
